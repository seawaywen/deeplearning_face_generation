# %% [markdown]
# # Face Generation
# In this project, you'll use generative adversarial networks to generate new images of faces.
# ### Get the Data
# You'll be using two datasets in this project:
# - MNIST
# - CelebA
#
# Since the celebA dataset is complex and you're doing GANs in a project for the first time, we want you to test your neural network on MNIST before CelebA.  Running the GANs on MNIST will allow you to see how well your model trains sooner.
#
# If you're using [FloydHub](https://www.floydhub.com/), set `data_dir` to "/input" and use the [FloydHub data ID](http://docs.floydhub.com/home/using_datasets/) "R5KrjnANiKVhLWAkpXhNBe".

# %%
data_dir = './data'

# FloydHub - Use with data ID "R5KrjnANiKVhLWAkpXhNBe"
#data_dir = '/input'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper

helper.download_extract('mnist', data_dir)
helper.download_extract('celeba', data_dir)
# Out:
# Found mnist Data
# Found celeba Data

# %% [markdown]
# ## Explore the Data
# ### MNIST
# As you're aware, the [MNIST](http://yann.lecun.com/exdb/mnist/) dataset contains images of handwritten digits. You can view the first number of examples by changing `show_n_images`.

# %%
show_n_images = 25

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
import os
from glob import glob
from matplotlib import pyplot

mnist_images = helper.get_batch(glob(os.path.join(data_dir, 'mnist/*.jpg'))[:show_n_images], 28, 28, 'L')
pyplot.imshow(helper.images_square_grid(mnist_images, 'L'), cmap='gray')

# %% [markdown]
# ### CelebA
# The [CelebFaces Attributes Dataset (CelebA)](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) dataset contains over 200,000 celebrity images with annotations.  Since you're going to be generating faces, you won't need the annotations.  You can view the first number of examples by changing `show_n_images`.

# %%
show_n_images = 25

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
mnist_images = helper.get_batch(glob(os.path.join(data_dir, 'img_align_celeba/*.jpg'))[:show_n_images], 28, 28, 'RGB')
pyplot.imshow(helper.images_square_grid(mnist_images, 'RGB'))

# %% [markdown]
# ## Preprocess the Data
# Since the project's main focus is on building the GANs, we'll preprocess the data for you.  The values of the MNIST and CelebA dataset will be in the range of -0.5 to 0.5 of 28x28 dimensional images.  The CelebA images will be cropped to remove parts of the image that don't include a face, then resized down to 28x28.
#
# The MNIST images are black and white images with a single [color channel](https://en.wikipedia.org/wiki/Channel_(digital_image%29) while the CelebA images have [3 color channels (RGB color channel)](https://en.wikipedia.org/wiki/Channel_(digital_image%29#RGB_Images).
# ## Build the Neural Network
# You'll build the components necessary to build a GANs by implementing the following functions below:
# - `model_inputs`
# - `discriminator`
# - `generator`
# - `model_loss`
# - `model_opt`
# - `train`
#
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.0'), 'Please use TensorFlow version 1.0 or newer.  You are using {}'.format(tf.__version__)
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.0.0
# Default GPU Device: /gpu:0

# %% [markdown]
# ### Input
# Implement the `model_inputs` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
# - Real input images placeholder with rank 4 using `image_width`, `image_height`, and `image_channels`.
# - Z input placeholder with rank 2 using `z_dim`.
# - Learning rate placeholder with rank 0.
#
# Return the placeholders in the following the tuple (tensor of real input images, tensor of z data)

# %%
import problem_unittests as tests

def model_inputs(image_width, image_height, image_channels, z_dim):
    """
    Create the model inputs
    :param image_width: The input image width
    :param image_height: The input image height
    :param image_channels: The number of image channels
    :param z_dim: The dimension of Z
    :return: Tuple of (tensor of real input images, tensor of z data, learning rate)
    """
    # TODO: Implement Function
    real_image_inputs = tf.placeholder(tf.float32, 
                                      (None, image_width, image_height, image_channels),
                                      name='real_image_inputs')
    z_inputs = tf.placeholder(tf.float32, 
                              (None, z_dim), 
                              name='z_inputs')
    learning_rate = tf.placeholder(tf.float32, name='learning_rate')

    return real_image_inputs, z_inputs, learning_rate


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### Discriminator
# Implement `discriminator` to create a discriminator neural network that discriminates on `images`.  This function should be able to reuse the variables in the neural network.  Use [`tf.variable_scope`](https://www.tensorflow.org/api_docs/python/tf/variable_scope) with a scope name of "discriminator" to allow the variables to be reused.  The function should return a tuple of (tensor output of the discriminator, tensor logits of the discriminator).

# %%
def discriminator(images, reuse=False):
    """
    Create the discriminator network
    :param images: Tensor of input image(s)
    :param reuse: Boolean if the weights should be reused
    :return: Tuple of (tensor output of the discriminator, tensor logits of the discriminator)
    """
    alpha = 0.1
    
    # TODO: Implement Function
    with tf.variable_scope('discriminator', reuse=reuse):
        
        # Input layer is 28x28x3
        layer1 = tf.layers.conv2d(
            images, filters=64, kernel_size=4, strides=2, padding='same')
        relu1 = tf.maximum(layer1, layer1 * alpha)
        # 14x14x64
        
        layer2 = tf.layers.conv2d(
            relu1, filters=128, kernel_size=4, strides=2, padding='same')
        layer2 = tf.layers.batch_normalization(layer2, training=True)
        relu2 = tf.maximum(layer2, layer2 * alpha)
        # 7x7x128

        layer3 = tf.layers.conv2d(
            relu2, filters=256, kernel_size=4, strides=2, padding='same')
        layer3 = tf.layers.batch_normalization(layer3, training=True)
        relu3 = tf.maximum(layer3, layer3 * alpha)
        # 4x4x256
        
        flatten_input = tf.reshape(relu3, (-1, 4 * 4 * 256))
        logits = tf.layers.dense(flatten_input, 1)
        output = tf.sigmoid(logits)

        return output, logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_discriminator(discriminator, tf)
# Out:
# Tests Passed

# %% [markdown]
# ### Generator
# Implement `generator` to generate an image using `z`. This function should be able to reuse the variables in the neural network.  Use [`tf.variable_scope`](https://www.tensorflow.org/api_docs/python/tf/variable_scope) with a scope name of "generator" to allow the variables to be reused. The function should return the generated 28 x 28 x `out_channel_dim` images.

# %%
def generator(z, out_channel_dim, is_train=True):
    """
    Create the generator network
    :param z: Input z
    :param out_channel_dim: The number of channels in the output image
    :param is_train: Boolean if generator is being used for training
    :return: The tensor output of the generator
    """
    alpha = 0.1
    
    # TODO: Implement Function
    with tf.variable_scope('generator', reuse=not is_train):
        
        layer1 = tf.layers.dense(z, 4 * 4 * 64)
        layer1 = tf.reshape(layer1, (-1, 4, 4, 64))
        layer1 = tf.layers.batch_normalization(layer1, training=is_train)
        relu1 = tf.maximum(layer1, layer1 * alpha)
        # 4x4x64 #512
        
        layer2 = tf.layers.conv2d_transpose(
            relu1, filters=32, kernel_size=4, strides=1, padding='valid')
        layer2 = tf.layers.batch_normalization(layer2, training=is_train)
        relu2 = tf.maximum(layer2, layer2 * alpha)
        # 7x7x32 #256

        layer3 = tf.layers.conv2d_transpose(
            relu2, filters=16, kernel_size=4, strides=2, padding='same')
        layer3 = tf.layers.batch_normalization(layer3, training=is_train)
        relu3 = tf.maximum(layer3, layer3 * alpha)
        # 14x14x16 #128
        
        logits = tf.layers.conv2d_transpose(
            relu3, filters=out_channel_dim, kernel_size=4, strides=2, padding='same')
        # 28x28xout_channel_dim
        
        output = tf.tanh(logits)
        
        return output


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_generator(generator, tf)
# Out:
# Tests Passed

# %% [markdown]
# ### Loss
# Implement `model_loss` to build the GANs for training and calculate the loss.  The function should return a tuple of (discriminator loss, generator loss).  Use the following functions you implemented:
# - `discriminator(images, reuse=False)`
# - `generator(z, out_channel_dim, is_train=True)`

# %%
def model_loss(input_real, input_z, out_channel_dim):
    """
    Get the loss for the discriminator and generator
    :param input_real: Images from the real dataset
    :param input_z: Z input
    :param out_channel_dim: The number of channels in the output image
    :return: A tuple of (discriminator loss, generator loss)
    """
    
    # TODO: Implement Function    
    g_model = generator(input_z, out_channel_dim)

    d_model_real, d_logits_real = discriminator(input_real)
    d_model_fake, d_logits_fake = discriminator(g_model, reuse=True)
    
    d_loss_real = tf.reduce_mean(
        tf.nn.sigmoid_cross_entropy_with_logits(
            logits=d_logits_real,
            labels=tf.ones_like(d_model_real * np.random.uniform(0.7, 1.2))))
    d_loss_fake = tf.reduce_mean(
        tf.nn.sigmoid_cross_entropy_with_logits(
            logits=d_logits_fake,
            labels=tf.zeros_like(d_model_fake)))
    d_loss = d_loss_real + d_loss_fake
    
    g_loss = tf.reduce_mean(
        tf.nn.sigmoid_cross_entropy_with_logits(
            logits=d_logits_fake,
            labels=tf.ones_like(d_model_fake)))
    
    return d_loss, g_loss


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_loss(model_loss)
# Out:
# Tests Passed

# %% [markdown]
# ### Optimization
# Implement `model_opt` to create the optimization operations for the GANs. Use [`tf.trainable_variables`](https://www.tensorflow.org/api_docs/python/tf/trainable_variables) to get all the trainable variables.  Filter the variables with names that are in the discriminator and generator scope names.  The function should return a tuple of (discriminator training operation, generator training operation).

# %%
def model_opt(d_loss, g_loss, learning_rate, beta1):
    """
    Get optimization operations
    :param d_loss: Discriminator loss Tensor
    :param g_loss: Generator loss Tensor
    :param learning_rate: Learning Rate Placeholder
    :param beta1: The exponential decay rate for the 1st moment in the optimizer
    :return: A tuple of (discriminator training operation, generator training operation)
    """
    # TODO: Implement Function
    tf_vars = tf.trainable_variables()
    d_vars = [var for var in tf_vars if var.name.startswith('discriminator')]
    g_vars = [var for var in tf_vars if var.name.startswith('generator')]

    operations = tf.get_collection(tf.GraphKeys.UPDATE_OPS)
    d_update_list = [opt for opt in operations if opt.name.startswith('discriminator')]
    g_update_list = [opt for opt in operations if opt.name.startswith('generator')]

    with tf.control_dependencies(d_update_list):
        d_train_optimizer = tf.train.AdamOptimizer(
            learning_rate, beta1=beta1).minimize(d_loss, var_list=d_vars)

    with tf.control_dependencies(g_update_list):    
        g_train_optimizer = tf.train.AdamOptimizer(
            learning_rate, beta1).minimize(g_loss, var_list=g_vars)
    
    return d_train_optimizer, g_train_optimizer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_opt(model_opt, tf)
# Out:
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Show Output
# Use this function to show the current output of the generator during training. It will help you determine how well the GANs is training.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

def show_generator_output(sess, n_images, input_z, out_channel_dim, image_mode):
    """
    Show example output for the generator
    :param sess: TensorFlow session
    :param n_images: Number of Images to display
    :param input_z: Input Z Tensor
    :param out_channel_dim: The number of channels in the output image
    :param image_mode: The mode to use for images ("RGB" or "L")
    """
    cmap = None if image_mode == 'RGB' else 'gray'
    z_dim = input_z.get_shape().as_list()[-1]
    example_z = np.random.uniform(-1, 1, size=[n_images, z_dim])

    samples = sess.run(
        generator(input_z, out_channel_dim, False),
        feed_dict={input_z: example_z})

    images_grid = helper.images_square_grid(samples, image_mode)
    pyplot.imshow(images_grid, cmap=cmap)
    pyplot.show()

# %% [markdown]
# ### Train
# Implement `train` to build and train the GANs.  Use the following functions you implemented:
# - `model_inputs(image_width, image_height, image_channels, z_dim)`
# - `model_loss(input_real, input_z, out_channel_dim)`
# - `model_opt(d_loss, g_loss, learning_rate, beta1)`
#
# Use the `show_generator_output` to show `generator` output while you train. Running `show_generator_output` for every batch will drastically increase training time and increase the size of the notebook.  It's recommended to print the `generator` output every 100 batches.

# %%
import pickle as pkl
import time

def train(epoch_count, batch_size, z_dim, learning_rate, beta1, get_batches, data_shape, data_image_mode):
    """
    Train the GAN
    :param epoch_count: Number of epochs
    :param batch_size: Batch Size
    :param z_dim: Z dimension
    :param learning_rate: Learning Rate
    :param beta1: The exponential decay rate for the 1st moment in the optimizer
    :param get_batches: Function to get batches
    :param data_shape: Shape of the data
    :param data_image_mode: The image mode to use for images ("RGB" or "L")
    """
    if not os.path.exists('checkpoints'):
        os.mkdir('checkpoints')
    
    # TODO: Build Model
    _, img_width, img_height, img_channels = data_shape
    
    real_input, z_input, lr = model_inputs(
        img_width, img_height, img_channels, z_dim)
    
    d_loss, g_loss = model_loss(real_input, z_input, img_channels)
    d_opt, g_opt = model_opt(d_loss, g_loss, learning_rate, beta1)
    
    n_images = 25
    index = 0 
    print_every = 10
    show_every = 100
    losses, samples = [], []  
    
    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        saver = tf.train.Saver()
        for epoch_i in range(epoch_count):
            for batch_images in get_batches(batch_size):
                # TODO: Train Model
                start_time = time.time()
                
                index += 1     
                batch_images *= 2.0
                
                # Sample random noise for generator              
                z_sample = np.random.uniform(-1, 1, (batch_size, z_dim))
                
                _ = sess.run(d_opt, feed_dict={
                    real_input: batch_images, 
                    z_input: z_sample,
                    lr: learning_rate
                })
                
                _ = sess.run(g_opt, feed_dict={
                    z_input: z_sample,
                    lr: learning_rate
                })
                
                if index % print_every == 0:
                    # grab the losses and print the ouput at the end of each epoch
                    train_d_loss = d_loss.eval({
                        z_input: z_sample,
                        real_input: batch_images
                    })

                    train_g_loss = g_loss.eval({z_input: z_sample})

                    print("Epoch {}/{}...".format(epoch_i + 1, epoch_count),
                          "Discriminator Loss: {:.4f}...".format(train_d_loss),
                          "Generator Loss: {:.4f}".format(train_g_loss),
                          "... (time: {:.4f})".format(time.time() - start_time))
                    losses.append((train_d_loss, train_g_loss))
                                
                if index % show_every == 0:
                    gen_sample = sess.run(
                        generator(z_input, img_channels, is_train=False),
                        feed_dict={z_input: z_sample})
                    samples.append(gen_sample)
                    show_generator_output(sess, n_images, z_input, img_channels, data_image_mode)

        saver.save(sess, './checkpoints/generator.ckpt')
        
    with open('samples.pkl', 'wb') as f:
        pkl.dump(samples, f)

# %% [markdown]
# ### MNIST
# Test your GANs architecture on MNIST.  After 2 epochs, the GANs should be able to generate images that look like handwritten digits.  Make sure the loss of the generator is lower than the loss of the discriminator or close to 0.

# %%
batch_size = 64
z_dim = 100
learning_rate = 0.0002
beta1 = 0.5


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
epochs = 2

mnist_dataset = helper.Dataset('mnist', glob(os.path.join(data_dir, 'mnist/*.jpg')))
#print(mnist_dataset.shape)
with tf.Graph().as_default():
    train(epochs, batch_size, z_dim, learning_rate, beta1, mnist_dataset.get_batches,
          mnist_dataset.shape, mnist_dataset.image_mode)
# Out:
# Epoch 1/2... Discriminator Loss: 0.0252... Generator Loss: 9.0847 ... (time: 0.6555)
# Epoch 1/2... Discriminator Loss: 0.1033... Generator Loss: 15.3740 ... (time: 0.5869)
# Epoch 1/2... Discriminator Loss: 0.0258... Generator Loss: 8.9726 ... (time: 0.5857)
# Epoch 1/2... Discriminator Loss: 0.0406... Generator Loss: 6.7253 ... (time: 0.5847)
# Epoch 1/2... Discriminator Loss: 0.0589... Generator Loss: 4.2997 ... (time: 0.5865)
# Epoch 1/2... Discriminator Loss: 1.6383... Generator Loss: 13.7453 ... (time: 0.5844)
# Epoch 1/2... Discriminator Loss: 1.5831... Generator Loss: 17.6203 ... (time: 0.5855)
# Epoch 1/2... Discriminator Loss: 0.0445... Generator Loss: 11.3632 ... (time: 0.5863)
# Epoch 1/2... Discriminator Loss: 0.2920... Generator Loss: 2.6412 ... (time: 0.5849)
# Epoch 1/2... Discriminator Loss: 0.1168... Generator Loss: 2.4043 ... (time: 0.5862)
# Epoch 1/2... Discriminator Loss: 0.5904... Generator Loss: 2.9821 ... (time: 0.5864)
# Epoch 1/2... Discriminator Loss: 0.4407... Generator Loss: 1.5727 ... (time: 0.5860)
# Epoch 1/2... Discriminator Loss: 0.2659... Generator Loss: 4.2503 ... (time: 0.5866)
# Epoch 1/2... Discriminator Loss: 0.1271... Generator Loss: 5.5695 ... (time: 0.5859)
# Epoch 1/2... Discriminator Loss: 0.6483... Generator Loss: 2.0123 ... (time: 0.5854)
# Epoch 1/2... Discriminator Loss: 3.9590... Generator Loss: 6.3426 ... (time: 0.5861)
# Epoch 1/2... Discriminator Loss: 0.5986... Generator Loss: 2.0528 ... (time: 0.5872)
# Epoch 1/2... Discriminator Loss: 1.9783... Generator Loss: 5.5061 ... (time: 0.5856)
# Epoch 1/2... Discriminator Loss: 1.3289... Generator Loss: 0.6579 ... (time: 0.5862)
# Epoch 1/2... Discriminator Loss: 2.5178... Generator Loss: 5.0521 ... (time: 0.5865)
# Epoch 1/2... Discriminator Loss: 2.2135... Generator Loss: 0.2507 ... (time: 0.5863)
# Epoch 1/2... Discriminator Loss: 1.2844... Generator Loss: 0.8949 ... (time: 0.5866)
# Epoch 1/2... Discriminator Loss: 0.9808... Generator Loss: 0.7815 ... (time: 0.5876)
# Epoch 1/2... Discriminator Loss: 0.9365... Generator Loss: 1.5425 ... (time: 0.5864)
# Epoch 1/2... Discriminator Loss: 1.4903... Generator Loss: 5.1198 ... (time: 0.5849)
# Epoch 1/2... Discriminator Loss: 0.5160... Generator Loss: 1.7010 ... (time: 0.5865)
# Epoch 1/2... Discriminator Loss: 0.8389... Generator Loss: 2.2175 ... (time: 0.5852)
# Epoch 1/2... Discriminator Loss: 0.7714... Generator Loss: 1.9686 ... (time: 0.5854)
# Epoch 1/2... Discriminator Loss: 0.6415... Generator Loss: 2.0872 ... (time: 0.5866)
# Epoch 1/2... Discriminator Loss: 0.9864... Generator Loss: 1.0191 ... (time: 0.5858)
# Epoch 1/2... Discriminator Loss: 0.8389... Generator Loss: 1.2128 ... (time: 0.5855)
# Epoch 1/2... Discriminator Loss: 0.7525... Generator Loss: 1.5094 ... (time: 0.5852)
# Epoch 1/2... Discriminator Loss: 1.0119... Generator Loss: 0.8238 ... (time: 0.5858)
# Epoch 1/2... Discriminator Loss: 1.0837... Generator Loss: 1.3020 ... (time: 0.5875)
# Epoch 1/2... Discriminator Loss: 1.4837... Generator Loss: 0.4527 ... (time: 0.5864)
# Epoch 1/2... Discriminator Loss: 2.2070... Generator Loss: 0.2013 ... (time: 0.5862)
# Epoch 1/2... Discriminator Loss: 1.1701... Generator Loss: 0.9113 ... (time: 0.5852)
# Epoch 1/2... Discriminator Loss: 1.5755... Generator Loss: 2.9168 ... (time: 0.5855)
# Epoch 1/2... Discriminator Loss: 1.3550... Generator Loss: 0.5437 ... (time: 0.5857)
# Epoch 1/2... Discriminator Loss: 1.6665... Generator Loss: 0.3864 ... (time: 0.5877)
# Epoch 1/2... Discriminator Loss: 0.8865... Generator Loss: 1.0617 ... (time: 0.5864)
# Epoch 1/2... Discriminator Loss: 1.0844... Generator Loss: 1.5419 ... (time: 0.5868)
# Epoch 1/2... Discriminator Loss: 0.9324... Generator Loss: 1.0354 ... (time: 0.5855)
# Epoch 1/2... Discriminator Loss: 1.0352... Generator Loss: 1.5297 ... (time: 0.5871)
# Epoch 1/2... Discriminator Loss: 1.1191... Generator Loss: 0.7054 ... (time: 0.5860)
# Epoch 1/2... Discriminator Loss: 1.2086... Generator Loss: 0.6946 ... (time: 0.5855)
# Epoch 2/2... Discriminator Loss: 1.0534... Generator Loss: 0.8229 ... (time: 0.5849)
# Epoch 2/2... Discriminator Loss: 0.9677... Generator Loss: 1.4144 ... (time: 0.5863)
# Epoch 2/2... Discriminator Loss: 1.2378... Generator Loss: 0.5576 ... (time: 0.5861)
# Epoch 2/2... Discriminator Loss: 1.2060... Generator Loss: 0.7983 ... (time: 0.5840)
# Epoch 2/2... Discriminator Loss: 1.0391... Generator Loss: 0.9504 ... (time: 0.5859)
# Epoch 2/2... Discriminator Loss: 1.5810... Generator Loss: 2.5079 ... (time: 0.5847)
# Epoch 2/2... Discriminator Loss: 1.6155... Generator Loss: 0.3713 ... (time: 0.5867)
# Epoch 2/2... Discriminator Loss: 1.2532... Generator Loss: 1.8797 ... (time: 0.5867)
# Epoch 2/2... Discriminator Loss: 1.6001... Generator Loss: 1.6489 ... (time: 0.5880)
# Epoch 2/2... Discriminator Loss: 1.7679... Generator Loss: 2.6489 ... (time: 0.5827)
# Epoch 2/2... Discriminator Loss: 1.0036... Generator Loss: 1.1776 ... (time: 0.5866)
# Epoch 2/2... Discriminator Loss: 1.1860... Generator Loss: 0.5846 ... (time: 0.5861)
# Epoch 2/2... Discriminator Loss: 1.4262... Generator Loss: 0.4668 ... (time: 0.5852)
# Epoch 2/2... Discriminator Loss: 1.2994... Generator Loss: 0.4764 ... (time: 0.5885)
# Epoch 2/2... Discriminator Loss: 1.1543... Generator Loss: 0.5738 ... (time: 0.5828)
# Epoch 2/2... Discriminator Loss: 1.5359... Generator Loss: 1.3450 ... (time: 0.5837)
# Epoch 2/2... Discriminator Loss: 0.9742... Generator Loss: 1.1616 ... (time: 0.5864)
# Epoch 2/2... Discriminator Loss: 0.9630... Generator Loss: 1.3085 ... (time: 0.5850)
# Epoch 2/2... Discriminator Loss: 1.2031... Generator Loss: 0.8421 ... (time: 0.5840)
# Epoch 2/2... Discriminator Loss: 1.3758... Generator Loss: 0.4497 ... (time: 0.5848)
# Epoch 2/2... Discriminator Loss: 1.1253... Generator Loss: 1.4102 ... (time: 0.5874)
# Epoch 2/2... Discriminator Loss: 1.0508... Generator Loss: 0.7659 ... (time: 0.5888)
# Epoch 2/2... Discriminator Loss: 1.1027... Generator Loss: 0.8402 ... (time: 0.5864)
# Epoch 2/2... Discriminator Loss: 1.5628... Generator Loss: 0.3676 ... (time: 0.5854)
# Epoch 2/2... Discriminator Loss: 1.2418... Generator Loss: 0.6808 ... (time: 0.5866)
# Epoch 2/2... Discriminator Loss: 1.1786... Generator Loss: 0.6249 ... (time: 0.5858)
# Epoch 2/2... Discriminator Loss: 0.9435... Generator Loss: 1.2847 ... (time: 0.5856)
# Epoch 2/2... Discriminator Loss: 1.0341... Generator Loss: 1.1729 ... (time: 0.5839)
# Epoch 2/2... Discriminator Loss: 1.1967... Generator Loss: 0.6937 ... (time: 0.5855)
# Epoch 2/2... Discriminator Loss: 1.5618... Generator Loss: 2.2988 ... (time: 0.5862)
# Epoch 2/2... Discriminator Loss: 1.1801... Generator Loss: 1.0886 ... (time: 0.5841)
# Epoch 2/2... Discriminator Loss: 1.3605... Generator Loss: 0.5697 ... (time: 0.5856)
# Epoch 2/2... Discriminator Loss: 1.0457... Generator Loss: 0.9247 ... (time: 0.5853)
# Epoch 2/2... Discriminator Loss: 0.9931... Generator Loss: 1.1895 ... (time: 0.5856)
# Epoch 2/2... Discriminator Loss: 1.1179... Generator Loss: 0.6280 ... (time: 0.5859)
# Epoch 2/2... Discriminator Loss: 1.0550... Generator Loss: 1.0984 ... (time: 0.5880)
# Epoch 2/2... Discriminator Loss: 1.1989... Generator Loss: 0.8249 ... (time: 0.5854)
# Epoch 2/2... Discriminator Loss: 0.9559... Generator Loss: 0.9377 ... (time: 0.5861)
# Epoch 2/2... Discriminator Loss: 1.8727... Generator Loss: 0.2416 ... (time: 0.5855)
# Epoch 2/2... Discriminator Loss: 1.2442... Generator Loss: 0.5239 ... (time: 0.5859)
# Epoch 2/2... Discriminator Loss: 1.4005... Generator Loss: 1.9969 ... (time: 0.5863)
# Epoch 2/2... Discriminator Loss: 1.0341... Generator Loss: 0.7412 ... (time: 0.5851)
# Epoch 2/2... Discriminator Loss: 1.0669... Generator Loss: 1.2120 ... (time: 0.5865)
# Epoch 2/2... Discriminator Loss: 1.2304... Generator Loss: 0.5815 ... (time: 0.5885)
# Epoch 2/2... Discriminator Loss: 1.0558... Generator Loss: 0.8993 ... (time: 0.5864)
# Epoch 2/2... Discriminator Loss: 1.0788... Generator Loss: 0.8727 ... (time: 0.5861)
# Epoch 2/2... Discriminator Loss: 1.0726... Generator Loss: 1.2161 ... (time: 0.5852)

# %% [markdown]
# # CelebA
# Run your GANs on CelebA.  It will take around 20 minutes on the average GPU to run one epoch.  You can run the whole epoch or stop when it starts to generate realistic faces.

# %%
batch_size = 64
z_dim = 100
learning_rate = 0.0002
beta1 = 0.5


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
epochs = 1

celeba_dataset = helper.Dataset('celeba', glob(os.path.join(data_dir, 'img_align_celeba/*.jpg')))
with tf.Graph().as_default():
    train(epochs, batch_size, z_dim, learning_rate, beta1, celeba_dataset.get_batches,
          celeba_dataset.shape, celeba_dataset.image_mode)
# Out:
# Epoch 1/1... Discriminator Loss: 0.7940... Generator Loss: 14.6371 ... (time: 0.6709)
# Epoch 1/1... Discriminator Loss: 0.2528... Generator Loss: 1.7579 ... (time: 0.5974)
# Epoch 1/1... Discriminator Loss: 0.0482... Generator Loss: 8.5419 ... (time: 0.5989)
# Epoch 1/1... Discriminator Loss: 0.0355... Generator Loss: 8.6838 ... (time: 0.5976)
# Epoch 1/1... Discriminator Loss: 0.1817... Generator Loss: 6.7910 ... (time: 0.5974)
# Epoch 1/1... Discriminator Loss: 0.0241... Generator Loss: 7.7630 ... (time: 0.5984)
# Epoch 1/1... Discriminator Loss: 1.7583... Generator Loss: 0.2008 ... (time: 0.5974)
# Epoch 1/1... Discriminator Loss: 0.7947... Generator Loss: 1.0001 ... (time: 0.6008)
# Epoch 1/1... Discriminator Loss: 0.2315... Generator Loss: 2.5229 ... (time: 0.5986)
# Epoch 1/1... Discriminator Loss: 0.1001... Generator Loss: 3.0503 ... (time: 0.5979)
# Epoch 1/1... Discriminator Loss: 0.1955... Generator Loss: 2.3626 ... (time: 0.5981)
# Epoch 1/1... Discriminator Loss: 0.1553... Generator Loss: 2.6858 ... (time: 0.5994)
# Epoch 1/1... Discriminator Loss: 0.7663... Generator Loss: 0.8260 ... (time: 0.5980)
# Epoch 1/1... Discriminator Loss: 1.1769... Generator Loss: 4.5714 ... (time: 0.5976)
# Epoch 1/1... Discriminator Loss: 0.8092... Generator Loss: 1.2649 ... (time: 0.5974)
# Epoch 1/1... Discriminator Loss: 0.6041... Generator Loss: 1.4484 ... (time: 0.5979)
# Epoch 1/1... Discriminator Loss: 0.3565... Generator Loss: 7.4684 ... (time: 0.5980)
# Epoch 1/1... Discriminator Loss: 1.0805... Generator Loss: 0.8243 ... (time: 0.5971)
# Epoch 1/1... Discriminator Loss: 0.3495... Generator Loss: 2.0832 ... (time: 0.5961)
# Epoch 1/1... Discriminator Loss: 0.2029... Generator Loss: 2.7644 ... (time: 0.5959)
# Epoch 1/1... Discriminator Loss: 0.1961... Generator Loss: 3.2615 ... (time: 0.5990)
# Epoch 1/1... Discriminator Loss: 0.8101... Generator Loss: 6.4707 ... (time: 0.5979)
# Epoch 1/1... Discriminator Loss: 0.2154... Generator Loss: 3.6728 ... (time: 0.5968)
# Epoch 1/1... Discriminator Loss: 1.1635... Generator Loss: 0.8059 ... (time: 0.5968)
# Epoch 1/1... Discriminator Loss: 0.7158... Generator Loss: 1.6136 ... (time: 0.5979)
# Epoch 1/1... Discriminator Loss: 0.4538... Generator Loss: 2.2029 ... (time: 0.5985)
# Epoch 1/1... Discriminator Loss: 0.5624... Generator Loss: 2.2791 ... (time: 0.5968)
# Epoch 1/1... Discriminator Loss: 0.6503... Generator Loss: 1.2679 ... (time: 0.5980)
# Epoch 1/1... Discriminator Loss: 0.5494... Generator Loss: 3.2277 ... (time: 0.5983)
# Epoch 1/1... Discriminator Loss: 0.7004... Generator Loss: 2.3359 ... (time: 0.5967)
# Epoch 1/1... Discriminator Loss: 0.8235... Generator Loss: 1.0096 ... (time: 0.5956)
# Epoch 1/1... Discriminator Loss: 1.1804... Generator Loss: 0.6203 ... (time: 0.5968)
# Epoch 1/1... Discriminator Loss: 0.7680... Generator Loss: 1.0783 ... (time: 0.5987)
# Epoch 1/1... Discriminator Loss: 0.6316... Generator Loss: 2.3976 ... (time: 0.5973)
# Epoch 1/1... Discriminator Loss: 1.5823... Generator Loss: 0.4864 ... (time: 0.5995)
# Epoch 1/1... Discriminator Loss: 0.6911... Generator Loss: 1.4443 ... (time: 0.5982)
# Epoch 1/1... Discriminator Loss: 0.8684... Generator Loss: 0.9508 ... (time: 0.5962)
# Epoch 1/1... Discriminator Loss: 0.6495... Generator Loss: 1.1271 ... (time: 0.5980)
# Epoch 1/1... Discriminator Loss: 0.7766... Generator Loss: 4.1800 ... (time: 0.5977)
# Epoch 1/1... Discriminator Loss: 0.6907... Generator Loss: 2.2262 ... (time: 0.5946)
# Epoch 1/1... Discriminator Loss: 0.5372... Generator Loss: 1.8188 ... (time: 0.5963)
# Epoch 1/1... Discriminator Loss: 0.6256... Generator Loss: 1.7444 ... (time: 0.5974)
# Epoch 1/1... Discriminator Loss: 1.3384... Generator Loss: 0.4409 ... (time: 0.5962)
# Epoch 1/1... Discriminator Loss: 0.5975... Generator Loss: 1.4877 ... (time: 0.5965)
# Epoch 1/1... Discriminator Loss: 1.1468... Generator Loss: 0.5191 ... (time: 0.5974)
# Epoch 1/1... Discriminator Loss: 0.9749... Generator Loss: 0.8614 ... (time: 0.5978)
# Epoch 1/1... Discriminator Loss: 1.0253... Generator Loss: 0.8734 ... (time: 0.5977)
# Epoch 1/1... Discriminator Loss: 1.1826... Generator Loss: 0.6641 ... (time: 0.5971)
# Epoch 1/1... Discriminator Loss: 0.5204... Generator Loss: 2.4680 ... (time: 0.5981)
# Epoch 1/1... Discriminator Loss: 0.7019... Generator Loss: 2.1795 ... (time: 0.5985)
# Epoch 1/1... Discriminator Loss: 1.9445... Generator Loss: 0.2515 ... (time: 0.5970)
# Epoch 1/1... Discriminator Loss: 1.4519... Generator Loss: 3.7520 ... (time: 0.5969)
# Epoch 1/1... Discriminator Loss: 0.6468... Generator Loss: 1.7790 ... (time: 0.5979)
# Epoch 1/1... Discriminator Loss: 0.8033... Generator Loss: 1.8116 ... (time: 0.5972)
# Epoch 1/1... Discriminator Loss: 0.8398... Generator Loss: 2.6334 ... (time: 0.5969)
# Epoch 1/1... Discriminator Loss: 0.6324... Generator Loss: 1.4584 ... (time: 0.5981)
# Epoch 1/1... Discriminator Loss: 0.9776... Generator Loss: 1.2844 ... (time: 0.5970)
# Epoch 1/1... Discriminator Loss: 1.2878... Generator Loss: 0.5170 ... (time: 0.5976)
# Epoch 1/1... Discriminator Loss: 0.7854... Generator Loss: 1.8961 ... (time: 0.5974)
# Epoch 1/1... Discriminator Loss: 0.5512... Generator Loss: 2.0286 ... (time: 0.5985)
# Epoch 1/1... Discriminator Loss: 0.6118... Generator Loss: 1.8302 ... (time: 0.5968)
# Epoch 1/1... Discriminator Loss: 0.7281... Generator Loss: 0.9846 ... (time: 0.6012)
# Epoch 1/1... Discriminator Loss: 0.6468... Generator Loss: 1.2116 ... (time: 0.5990)
# Epoch 1/1... Discriminator Loss: 1.1683... Generator Loss: 0.6379 ... (time: 0.5987)
# Epoch 1/1... Discriminator Loss: 0.7920... Generator Loss: 1.1234 ... (time: 0.5978)
# Epoch 1/1... Discriminator Loss: 0.6883... Generator Loss: 1.5552 ... (time: 0.5964)
# Epoch 1/1... Discriminator Loss: 0.5386... Generator Loss: 1.7621 ... (time: 0.5980)
# Epoch 1/1... Discriminator Loss: 0.3688... Generator Loss: 1.9352 ... (time: 0.5976)
# Epoch 1/1... Discriminator Loss: 0.7130... Generator Loss: 3.0288 ... (time: 0.5992)
# Epoch 1/1... Discriminator Loss: 0.6795... Generator Loss: 1.5018 ... (time: 0.5982)
# Epoch 1/1... Discriminator Loss: 0.7735... Generator Loss: 2.6106 ... (time: 0.5973)
# Epoch 1/1... Discriminator Loss: 0.7607... Generator Loss: 1.6864 ... (time: 0.5976)
# Epoch 1/1... Discriminator Loss: 0.2658... Generator Loss: 3.5698 ... (time: 0.5967)
# Epoch 1/1... Discriminator Loss: 0.5089... Generator Loss: 1.7792 ... (time: 0.5971)
# Epoch 1/1... Discriminator Loss: 0.8233... Generator Loss: 1.3700 ... (time: 0.5986)
# Epoch 1/1... Discriminator Loss: 1.1204... Generator Loss: 0.6740 ... (time: 0.5963)
# Epoch 1/1... Discriminator Loss: 0.6889... Generator Loss: 1.6375 ... (time: 0.5974)
# Epoch 1/1... Discriminator Loss: 0.6069... Generator Loss: 1.4159 ... (time: 0.5980)
# Epoch 1/1... Discriminator Loss: 0.9585... Generator Loss: 2.0135 ... (time: 0.5975)
# Epoch 1/1... Discriminator Loss: 0.6629... Generator Loss: 0.9819 ... (time: 0.5959)
# Epoch 1/1... Discriminator Loss: 0.5712... Generator Loss: 1.6223 ... (time: 0.5989)
# Epoch 1/1... Discriminator Loss: 0.7886... Generator Loss: 1.6840 ... (time: 0.5985)
# Epoch 1/1... Discriminator Loss: 0.7240... Generator Loss: 1.2379 ... (time: 0.5972)
# Epoch 1/1... Discriminator Loss: 0.8506... Generator Loss: 1.2149 ... (time: 0.5995)
# Epoch 1/1... Discriminator Loss: 0.8328... Generator Loss: 0.9946 ... (time: 0.5982)
# Epoch 1/1... Discriminator Loss: 1.3044... Generator Loss: 0.5662 ... (time: 0.5983)
# Epoch 1/1... Discriminator Loss: 0.8519... Generator Loss: 1.1743 ... (time: 0.5982)
# Epoch 1/1... Discriminator Loss: 0.9165... Generator Loss: 1.4564 ... (time: 0.5971)
# Epoch 1/1... Discriminator Loss: 0.9560... Generator Loss: 1.1596 ... (time: 0.5986)
# Epoch 1/1... Discriminator Loss: 0.6843... Generator Loss: 1.1862 ... (time: 0.5965)
# Epoch 1/1... Discriminator Loss: 1.3079... Generator Loss: 0.5147 ... (time: 0.5972)
# Epoch 1/1... Discriminator Loss: 1.0499... Generator Loss: 1.0127 ... (time: 0.5986)
# Epoch 1/1... Discriminator Loss: 0.6477... Generator Loss: 1.5218 ... (time: 0.5989)
# Epoch 1/1... Discriminator Loss: 0.8517... Generator Loss: 1.0867 ... (time: 0.5989)
# Epoch 1/1... Discriminator Loss: 0.6584... Generator Loss: 1.3825 ... (time: 0.5992)
# Epoch 1/1... Discriminator Loss: 1.3176... Generator Loss: 0.5293 ... (time: 0.5970)
# Epoch 1/1... Discriminator Loss: 0.7354... Generator Loss: 1.0902 ... (time: 0.5976)
# Epoch 1/1... Discriminator Loss: 0.7387... Generator Loss: 1.2056 ... (time: 0.5975)
# Epoch 1/1... Discriminator Loss: 0.8963... Generator Loss: 0.9859 ... (time: 0.5984)
# Epoch 1/1... Discriminator Loss: 0.8665... Generator Loss: 0.9445 ... (time: 0.5981)
# Epoch 1/1... Discriminator Loss: 0.8749... Generator Loss: 1.1975 ... (time: 0.5978)
# Epoch 1/1... Discriminator Loss: 0.9921... Generator Loss: 0.7874 ... (time: 0.5995)
# Epoch 1/1... Discriminator Loss: 0.8630... Generator Loss: 1.2822 ... (time: 0.5979)
# Epoch 1/1... Discriminator Loss: 0.6962... Generator Loss: 1.6056 ... (time: 0.5967)
# Epoch 1/1... Discriminator Loss: 1.1221... Generator Loss: 0.7560 ... (time: 0.5967)
# Epoch 1/1... Discriminator Loss: 0.8377... Generator Loss: 1.3552 ... (time: 0.5965)
# Epoch 1/1... Discriminator Loss: 0.8592... Generator Loss: 0.9791 ... (time: 0.5974)
# Epoch 1/1... Discriminator Loss: 0.9785... Generator Loss: 0.9426 ... (time: 0.5982)
# Epoch 1/1... Discriminator Loss: 0.8260... Generator Loss: 1.5402 ... (time: 0.5963)
# Epoch 1/1... Discriminator Loss: 0.9413... Generator Loss: 0.8663 ... (time: 0.5977)
# Epoch 1/1... Discriminator Loss: 0.7892... Generator Loss: 1.3681 ... (time: 0.6028)
# Epoch 1/1... Discriminator Loss: 0.9977... Generator Loss: 0.6594 ... (time: 0.5968)
# Epoch 1/1... Discriminator Loss: 0.8775... Generator Loss: 0.8780 ... (time: 0.5982)
# Epoch 1/1... Discriminator Loss: 0.8405... Generator Loss: 1.3264 ... (time: 0.5971)
# Epoch 1/1... Discriminator Loss: 0.9215... Generator Loss: 1.0906 ... (time: 0.5968)
# Epoch 1/1... Discriminator Loss: 1.5407... Generator Loss: 3.2532 ... (time: 0.5965)
# Epoch 1/1... Discriminator Loss: 0.9558... Generator Loss: 1.1009 ... (time: 0.5969)
# Epoch 1/1... Discriminator Loss: 1.1834... Generator Loss: 0.6226 ... (time: 0.5969)
# Epoch 1/1... Discriminator Loss: 0.6967... Generator Loss: 1.4205 ... (time: 0.5956)
# Epoch 1/1... Discriminator Loss: 0.7801... Generator Loss: 1.2357 ... (time: 0.5975)
# Epoch 1/1... Discriminator Loss: 1.0430... Generator Loss: 0.6649 ... (time: 0.5986)
# Epoch 1/1... Discriminator Loss: 0.9397... Generator Loss: 2.4080 ... (time: 0.5984)
# Epoch 1/1... Discriminator Loss: 0.8247... Generator Loss: 1.4837 ... (time: 0.5989)
# Epoch 1/1... Discriminator Loss: 0.8067... Generator Loss: 1.8468 ... (time: 0.5967)
# Epoch 1/1... Discriminator Loss: 0.8670... Generator Loss: 1.7065 ... (time: 0.5959)
# Epoch 1/1... Discriminator Loss: 0.7166... Generator Loss: 1.3497 ... (time: 0.5981)
# Epoch 1/1... Discriminator Loss: 0.7100... Generator Loss: 1.5793 ... (time: 0.5958)
# Epoch 1/1... Discriminator Loss: 0.7148... Generator Loss: 1.3274 ... (time: 0.5967)
# Epoch 1/1... Discriminator Loss: 1.0692... Generator Loss: 0.6691 ... (time: 0.5982)
# Epoch 1/1... Discriminator Loss: 1.0924... Generator Loss: 0.6057 ... (time: 0.5973)
# Epoch 1/1... Discriminator Loss: 1.0098... Generator Loss: 0.8594 ... (time: 0.5976)
# Epoch 1/1... Discriminator Loss: 1.1156... Generator Loss: 0.6499 ... (time: 0.5962)
# Epoch 1/1... Discriminator Loss: 0.8344... Generator Loss: 2.5020 ... (time: 0.5973)
# Epoch 1/1... Discriminator Loss: 0.8532... Generator Loss: 2.0264 ... (time: 0.5985)
# Epoch 1/1... Discriminator Loss: 0.9087... Generator Loss: 0.9191 ... (time: 0.5974)
# Epoch 1/1... Discriminator Loss: 1.0263... Generator Loss: 0.7322 ... (time: 0.5990)
# Epoch 1/1... Discriminator Loss: 1.2127... Generator Loss: 0.5867 ... (time: 0.5967)
# Epoch 1/1... Discriminator Loss: 0.9904... Generator Loss: 1.3344 ... (time: 0.5968)
# Epoch 1/1... Discriminator Loss: 0.9533... Generator Loss: 0.8862 ... (time: 0.5978)
# Epoch 1/1... Discriminator Loss: 0.8971... Generator Loss: 0.9152 ... (time: 0.5979)
# Epoch 1/1... Discriminator Loss: 0.8063... Generator Loss: 1.4507 ... (time: 0.5983)
# Epoch 1/1... Discriminator Loss: 0.7263... Generator Loss: 1.1626 ... (time: 0.5991)
# Epoch 1/1... Discriminator Loss: 0.8407... Generator Loss: 1.5949 ... (time: 0.5996)
# Epoch 1/1... Discriminator Loss: 0.8506... Generator Loss: 1.8501 ... (time: 0.5990)
# Epoch 1/1... Discriminator Loss: 1.2446... Generator Loss: 1.3483 ... (time: 0.5965)
# Epoch 1/1... Discriminator Loss: 0.9499... Generator Loss: 0.7794 ... (time: 0.5984)
# Epoch 1/1... Discriminator Loss: 1.0074... Generator Loss: 0.7844 ... (time: 0.5973)
# Epoch 1/1... Discriminator Loss: 0.8742... Generator Loss: 1.2387 ... (time: 0.5981)
# Epoch 1/1... Discriminator Loss: 0.9719... Generator Loss: 2.2371 ... (time: 0.5960)
# Epoch 1/1... Discriminator Loss: 1.0246... Generator Loss: 2.1052 ... (time: 0.5972)
# Epoch 1/1... Discriminator Loss: 0.8714... Generator Loss: 0.9764 ... (time: 0.5989)
# Epoch 1/1... Discriminator Loss: 0.9294... Generator Loss: 1.1417 ... (time: 0.5970)
# Epoch 1/1... Discriminator Loss: 0.8486... Generator Loss: 1.0799 ... (time: 0.5983)
# Epoch 1/1... Discriminator Loss: 1.3230... Generator Loss: 0.7899 ... (time: 0.5969)
# Epoch 1/1... Discriminator Loss: 1.0837... Generator Loss: 0.7741 ... (time: 0.5986)
# Epoch 1/1... Discriminator Loss: 0.8999... Generator Loss: 1.0915 ... (time: 0.5974)
# Epoch 1/1... Discriminator Loss: 0.5564... Generator Loss: 1.5530 ... (time: 0.5969)
# Epoch 1/1... Discriminator Loss: 0.9688... Generator Loss: 1.5807 ... (time: 0.5963)

# %% [markdown]
# ### Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_face_generation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
